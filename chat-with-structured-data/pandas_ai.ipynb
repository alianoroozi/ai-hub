# %%
# !pip install pandasai-openai

# %%
import os
import pandasai as pai
from pandasai_openai import OpenAI

llm = OpenAI()

# %%
llm.model
# Out:
# 'gpt-4o-mini'

# %%
pai.config.set({
    "llm": llm,
})

# %%
pai.api_key.set(os.environ.get("PAI_API_KEY"))

# %%
df = pai.load("pai-personal-7ac6e/spend-data")
# Out:
# Dataset loaded successfully.

# %%
user_query = "Show me the total cost of items ordered by the Electronics department from vendor OfficeMax Corp in feb 2024."
result = df.chat(user_query)
# Out:
# /Users/ali/Workspace/Workspace2/spend-assistant/.venv/lib/python3.11/site-packages/jinja2/runtime.py:303: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return __obj(*args, **kwargs)

# %%
result
# Out:
# NumberResponse(type='number', value=5202.83)

# %%
user_query = "What is my total monthly spend?"
result = df.chat(user_query)
# Out:
# /Users/ali/Workspace/Workspace2/spend-assistant/.venv/lib/python3.11/site-packages/jinja2/runtime.py:303: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return __obj(*args, **kwargs)
# /Users/ali/Workspace/Workspace2/spend-assistant/.venv/lib/python3.11/site-packages/jinja2/runtime.py:303: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return __obj(*args, **kwargs)

# %%
result
# Out:
# DataFrameResponse(type='dataframe', value=        month  total_spend
# 0  2023-03-01     22726.32
# 1  2023-04-01     48214.83
# 2  2023-05-01     56042.78
# 3  2023-06-01     58842.88
# 4  2023-07-01     54117.38
# 5  2023-08-01     62244.16
# 6  2023-09-01     67863.41
# 7  2023-10-01     77359.80
# 8  2023-11-01     51144.98
# 9  2023-12-01     48259.30
# 10 2024-01-01     48231.75
# 11 2024-02-01     60406.52
# 12 2024-03-01     45859.41
# 13 2024-04-01     66457.39
# 14 2024-05-01     54869.04
# 15 2024-06-01     58272.80
# 16 2024-07-01     62506.55
# 17 2024-08-01     73798.95
# 18 2024-09-01     55271.95
# 19 2024-10-01     42967.47
# 20 2024-11-01     45513.67
# 21 2024-12-01     84386.69
# 22 2025-01-01     39351.93
# 23 2025-02-01     66616.26
# 24 2025-03-01     45109.78)

# %%
df.chat("hello")
# Out:
# /Users/ali/Workspace/Workspace2/spend-assistant/.venv/lib/python3.11/site-packages/jinja2/runtime.py:303: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return __obj(*args, **kwargs)
# DataFrameResponse(type='dataframe', value=   department_name  total_spend
# 0      Electronics    310595.70
# 1      Maintenance    289359.73
# 2  Office Supplies    271338.41
# 3        Furniture    268630.75
# 4          Kitchen    256511.41)
